# %% [markdown]
# <a href="https://colab.research.google.com/github/ayeshaeva100/Simulation-and-Modeling-Lab/blob/main/Lab_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.animation import FuncAnimation
from IPython.display import HTML


# Traffic light housing
ax.add_patch(patches.Rectangle((0, 0), 2, 6, fill=True, color='black'))

# Circles for lights
red_light = plt.Circle((1, 5), 0.5, color='grey')
yellow_light = plt.Circle((1, 3), 0.5, color='grey')
green_light = plt.Circle((1, 1), 0.5, color='grey')
ax.add_patch(red_light)
ax.add_patch(yellow_light)
ax.add_patch(green_light)

ax.set_xlim(0, 2)
ax.set_ylim(0, 6)
ax.axis('off')

# Light states: [RED, GREEN, YELLOW]
states = ['red', 'green', 'yellow']
durations = [50, 50, 20]  # in frames
state_index = [0]  # mutable to allow update in animation


def update(frame):
    idx = state_index[0]
    red_light.set_color('red' if idx == 0 else 'grey')
    green_light.set_color('green' if idx == 1 else 'grey')
    yellow_light.set_color('yellow' if idx == 2 else 'grey')

    durations_acc = sum(durations[:idx+1])
    if frame % sum(durations) == durations_acc - 1:
        state_index[0] = (state_index[0] + 1) % 3


ani = FuncAnimation(fig, update, frames=150, interval=100)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...
