# %% [markdown]
# <a href="https://colab.research.google.com/github/ayeshaeva100/Simulation-and-Modeling-Lab/blob/main/Assignment5_2215151159.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ASSIGNMENT - 5 :**
#
# **Dataset :** [15,17,16,14,18,20,19,15,21,22]
#
# **Instructions:**
# 1. Load the Dataset: Use the provided dataset in your colab
# 2. Extract Temperature Scores: Extract the temperatures from the dataset for analysis.
# 3. Center and Scale the Data: Define the mean and standard deviation for a normal
# distribution and center and scale the temperature data accordingly.
# 4. Perform the K-S Test: Use MATLAB’s kstest function to perform a one-sample K-S
# test on the scaled data.
# 5. Output the Results: Display the test decision (h), p-value, KS statistic
# 6. Plot the Empirical CDF: Generate a plot comparing the empirical CDF of the scaled
# temperature data with the standard normal CDF.
# 7. Write a Conclusion: Based on the results, write a short conclusion about whether the
# null hypothesis (that the temperatures come from a normal distribution) can be rejected.

# %%
import numpy as np
from scipy.stats import kstest, norm
import matplotlib.pyplot as plt

# %%
#Load the Dataset
temperature_data = [15,17,16,14,18,20,19,15,21,22]

#Extract Temperature Scores
temperatures= np.array(temperature_data)

# %%
#Center and Scale the Data
mean_val = np.mean(temperatures)  # Sample mean
std_dev = np.std(temperatures) # Sample standard deviation

scaled_data = (temperature_data - mean_val) / std_dev

# %%
#Perform the K-S Test
ks_result = kstest(scaled_data, 'norm')

# %%
#Output the Results
print(f"Test decision (h): {int(ks_result.pvalue < 0.05)}")
print(f"p-value: {ks_result.pvalue:.4f}")
print(f"KS statistic: {ks_result.statistic:.4f}")
# Out:
# Test decision (h): 0
# p-value: 0.9550
# KS statistic: 0.1496

# %%
#Plot the Empirical CDF
plt.figure()

# Empirical CDF data
ecdf = np.sort(scaled_data)
y = np.arange(1, len(ecdf) + 1) / len(ecdf)

plt.bar(ecdf, y, width=0.2, align='edge', color='gray', label='Empirical CDF')

# Standard Normal CDF
x = np.linspace(min(scaled_data), max(scaled_data), 100)
plt.plot(x, norm.cdf(x, 0, 1), 'r--', linewidth=2, label='Standard Normal CDF')

plt.legend()
plt.title('Empirical CDF vs Standard Normal CDF')
plt.xlabel('Standardized Temperature')
plt.ylabel('Cumulative Probability')
plt.grid(True)
plt.show()

# %% [markdown]
# **Conclusion:**
#
# Given the p-value of 0.9550 from the one-sample Kolmogorov-Smirnov test, which is well above the standard 0.05 significance level, there is insufficient evidence to reject the null hypothesis. This implies that the daily temperature data can be considered consistent with a normal distribution for the sample analyzed.
